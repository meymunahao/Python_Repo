# %%
#Project I
#Developing a python function program that takes a user's name and department, 
#then checks if he/she is an employee.

def company():
    nam = input("What is your name?")
    dep = input("What is your department?")
    
import csv
print("Welcome to JT Ventures!")
print()
print("This program checks if you are an employee in JT Ventures")

a = input("Do you wish to continue?( yes or no)")

if a == "yes":
    company()
    m_list = open("jt.ventures.csv","r")
    read = csv.read(m_list)

else:
    print("Thank you, however you are not an employee!")

# %%
#Project II
#Developing a python function program that tells a user how much to pay, 
#based on their location, and package weight. 

print("Welcome to Yega Services!")
print()
print("This progam tells you how much to pay based on your location and package weight")

location = input("Do you stay in Ibeju_lekki or Epe? ")
weight = int(input("Enter the weight of the package "))
if location == "Ibeju_leki" and weight == 10 or weight > 10:
    print("Your delivery payment is #2000")
elif location == "Ibeju_lekki" and weight < 10:
    print("Your delivery payment is #1500")
elif location == "Epe" and weight == 10 or weight > 10:
    print("Your delivery payment is #5000")
elif location == "Epe" and weight < 10:
    print("Your delivery payment is #4000")
else:
    print("We are sorry you do not live in the above vicinity, and thus cannot deliver ")

# %%
#Project III
#Developing a python function program that tells a particular candidate if he/she is admitted 
#into computer science, based on their inputs. 
#The program will store the information of candidates who are admitted into a file 
#called admitted.csv, and candidates who did not meet the requirements are stored in 
#another file called not-admitted.csv

def check_c():
   j_score = input("Was your jamb score 230 or above?")
   print("What were your grades(A,B,C,D,E,F) in your O'level exam in the following subjects: ")
    M = input("Mathematics")
    E = input("English Language")
    P = input("Physics")
    C = input("Chemistry")
    I = input("ICT")
   

   interview = input("Did you pass the interview ( yes or no)")
    y = "yes"
    n = "no"

   if M == "A" or M == "B" or M == "C" and P == "A" or P == "B" or P == "C" and 
    B == "A" or B == "B" or B == "C" and C == "A" or C == "B" or C == "C" and 
    E == "A" or E == "B" or E == "C" and interview == "y" and j_score == 230 or j_score > 230::
      print("You are successfully admitted to study Computer Science!")
    
   else:
      print("Unfortunately you did not make the criterium, and did not get admitted. However, don't give up, there's still a lot ahead of you.")

def check_m():
   j_score = input("Was your jamb score 230 or above?")
   print("What were your grades(A,B,C,D,E,F) in your O'level exam in the following subjects: ")
   m = input("Mathematics")
   l = input("Literature")
   G = input("Government")
   B = input("Christian Religious Studies(CRS)/Islamic Religious Studies(IRS)")
   e = input("English Language")

   interview = input("Did you pass the interview ( yes or no)")
   y = "yes"
   n = "no"

   if m == "A" or m == "B" or m == "C" and L == "A" or L == "B" or L == "C" and 
G == "A" or G == "B" or G == "C" and B == "A" or B == "B" or B == "C" and 
e == "A" or e == "B" or e == "C" and interview == "y" and j_score == 230 or j_score > 230:
    print("You are successfully admitted to study Mass Communication!")
    
   else:
    print("Unfortunately you did not make the criterium, and did not get admitted. However, don't give up, there's still a lot ahead of you.")
    
print("Welcome! this program checks your requirement for admission into either Computer Science or Mass Communication")
course = input("What course are you applying for? (C for Computer Science and M for Mass Communication)")

if course == "C":
    check_c()
elif course == "M":
    check_m()
else:
    print("Please choose one of the letters C or M")
